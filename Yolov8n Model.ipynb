# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/ibrahimalobaid/object-detection-carla-self-driving-car/README.dataset.txt
# /kaggle/input/datasets/ibrahimalobaid/object-detection-carla-self-driving-car/README.roboflow.txt
# /kaggle/input/datasets/ibrahimalobaid/object-detection-carla-self-driving-car/data.yaml
# /kaggle/input/datasets/ibrahimalobaid/object-detection-carla-self-driving-car/valid/labels/1511_jpg.rf.709b7ed91ef8a22fd47ecdf9ae51a227.txt
# /kaggle/input/datasets/ibrahimalobaid/object-detection-carla-self-driving-car/valid/labels/702_jpg.rf.74650b22e57630eaac1761c2d8ed6aa6.txt
# /kaggle/input/datasets/ibrahimalobaid/object-detection-carla-self-driving-car/valid/labels/929_jpg.rf.f00c73e8dcfb1f840db1e1b7ce8462c2.txt
# /kaggle/input/datasets/ibrahimalobaid/object-detection-carla-self-driving-car/valid/labels/1308_jpg.rf.be681ceeb6d191532133fc406d0d3324.txt
# /kaggle/input/datasets/ibrahimalobaid/object-detection-carla-self-driving-car/valid/labels/668_jpg.rf.7873f029874cb33d55cb08c6c9f1e41e.txt
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 26.0 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO('yolov8n.pt')

# %%
import os

for dirname, _, filenames in os.walk('/kaggle/input'):
    print(dirname)
# Out:
# /kaggle/input
# /kaggle/input/datasets
# /kaggle/input/datasets/ibrahimalobaid
# /kaggle/input/datasets/ibrahimalobaid/object-detection-carla-self-driving-car
# /kaggle/input/datasets/ibrahimalobaid/object-detection-carla-self-driving-car/valid
# /kaggle/input/datasets/ibrahimalobaid/object-detection-carla-self-driving-car/valid/labels
# /kaggle/input/datasets/ibrahimalobaid/object-detection-carla-self-driving-car/valid/images
# /kaggle/input/datasets/ibrahimalobaid/object-detection-carla-self-driving-car/test
# /kaggle/input/datasets/ibrahimalobaid/object-detection-carla-self-driving-car/test/labels
# /kaggle/input/datasets/ibrahimalobaid/object-detection-carla-self-driving-car/test/images
# /kaggle/input/datasets/ibrahimalobaid/object-detection-carla-self-driving-car/train
# /kaggle/input/datasets/ibrahimalobaid/object-detection-carla-self-driving-car/train/labels
# /kaggle/input/datasets/ibrahimalobaid/object-detection-carla-self-driving-car/train/images

# %%
data = """
train: /kaggle/input/datasets/ibrahimalobaid/object-detection-carla-self-driving-car/train/images
val: /kaggle/input/datasets/ibrahimalobaid/object-detection-carla-self-driving-car/valid/images
test: /kaggle/input/datasets/ibrahimalobaid/object-detection-carla-self-driving-car/test/images

nc: 4

names: ['car', 'truck', 'trafficLight', 'pedestrian']
"""

with open('/kaggle/working/data.yaml', 'w') as f:
    f.write(data)

print("data.yaml created")
# Out:
# data.yaml created

# %%
model.train(
    data='/kaggle/working/data.yaml',
    epochs=50,
    imgsz=640
)
# Out:
# Ultralytics 8.4.51 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
metrics = model.val()
# Out:
# Ultralytics 8.4.51 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.4±0.4 ms, read: 26.5±13.9 MB/s, size: 16.0 KB)
# val: Scanning /kaggle/input/datasets/ibrahimalobaid/object-detection-carla-self-driving-car/valid/labels... 320 images, 13 backgrounds, 238 corrupt: 100% ━━━━━━━━━━━━ 320/320 1.0Kit/s 0.3s
# val: /kaggle/input/datasets/ibrahimalobaid/object-detection-carla-self-driving-car/valid/images/0_jpg.rf.f9e0d464754e89bdca31152851c5ced1.jpg: ignoring corrupt image/label: Label class 6 exceeds dataset class count 4. Possible class labels are 0-3
# val: /kaggle/input/datasets/ibrahimalobaid/object-detection-carla-self-driving-car/valid/images/1001_jpg.rf.7f0c783831af6a799579c9bb7706e51b.jpg: ignoring corrupt image/label: Label class 5 exceeds dataset class count 4. Possible class labels are 0-3
# ...

# %%
import os

os.listdir('/kaggle/runs/detect/')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_22/1196387755.py in <cell line: 0>()
#       1 import os
#       2
# ----> 3 os.listdir('/kaggle/runs/detect/')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/kaggle/runs/detect/'

# %%
import os

os.listdir('runs/detect/')

# %%
from IPython.display import Image, display

display(Image(filename='runs/detect/train/results.png'))

# %%
from IPython.display import Image, display

display(Image(filename='runs/detect/train/confusion_matrix.png'))

# %%
results = model.predict(
    source='/kaggle/input/datasets/ibrahimalobaid/object-detection-carla-self-driving-car/test/images',
    save=True
)

# %%
import os
os.listdir('runs/detect/predict')

# %%
display(Image(filename='runs/detect/predict/YOUR_IMAGE_NAME'))

# %%
import os

os.listdir('runs/detect/predict')

# %%
['0001.jpg', '0002.jpg']

# %%
from IPython.display import Image, display

display(Image(filename='runs/detect/predict/0001.jpg'))

# %%
display(Image(filename='runs/detect/predict/0002.jpg'))

# %%
predict2

# %%
predict3

# %%
import os

os.listdir('runs/detect/')

# %%
from ultralytics import YOLO

model = YOLO('runs/detect/train/weights/best.pt')

results = model.predict(
    source='/kaggle/input/datasets/ibrahimalobaid/object-detection-carla-self-driving-car/test/images',
    save=True
)

# %%
# !pip install ultralytics

# %%
import os

os.listdir('/kaggle/working')

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt')

# %%
data = """
train: /kaggle/input/datasets/ibrahimalobaid/object-detection-carla-self-driving-car/train/images
val: /kaggle/input/datasets/ibrahimalobaid/object-detection-carla-self-driving-car/valid/images
test: /kaggle/input/datasets/ibrahimalobaid/object-detection-carla-self-driving-car/test/images

nc: 4

names: ['car', 'truck', 'trafficLight', 'pedestrian']
"""

with open('/kaggle/working/data.yaml', 'w') as f:
    f.write(data)

print("data.yaml created")

# %%
model.train(
    data='/kaggle/working/data.yaml',
    epochs=50,
    imgsz=640,
    project='/kaggle/working',
    name='carla_yolo'
)

# %%
import shutil

shutil.make_archive(
    '/kaggle/working/carla_yolo_results',
    'zip',
    '/kaggle/working/carla_yolo'
)

print("ZIP file created")

# %%
import os

os.listdir('/kaggle/working/carla_yolo')

# %%
from IPython.display import Image, display

display(Image(filename='/kaggle/working/carla_yolo/results.png'))

# %%
display(Image(filename='/kaggle/working/carla_yolo/confusion_matrix.png'))

# %%
display(Image(filename='/kaggle/working/carla_yolo/BoxPR_curve.png'))

# %%
display(Image(filename='/kaggle/working/carla_yolo/val_batch0_pred.jpg'))

# %%
import pandas as pd

df = pd.read_csv('/kaggle/working/carla_yolo/results.csv')

df.tail()

# %%
import pandas as pd

df = pd.read_csv('/kaggle/working/carla_yolo/results.csv')

df.tail(1)
